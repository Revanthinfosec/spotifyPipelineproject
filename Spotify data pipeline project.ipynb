# %%
# !pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_id = "fdac9ed2e4c1475183939d08a4893c53"
client_secret = "c97cc38d81d343a9a5b9e5dcfa031f24"
client_credentials_manager = SpotifyClientCredentials(client_id="fdac9ed2e4c1475183939d08a4893c53",client_secret="c97cc38d81d343a9a5b9e5dcfa031f24")

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_URI=playlist_link.split("/")[-1]

# %%
data=sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2023-12-21T09:51:14Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iHNK0tOyZPYnBU7nGAgpQ'},
#       'href': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ',
#       'id': '4iHNK0tOyZPYnBU7nGAgpQ',
#       'name': 'Mariah Carey',
#       'type': 'artist',
#       'uri': 'spotify:artist:4iHNK0tOyZPYnBU7nGAgpQ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '61ulfFSmmxMhc2wCdmdMkN'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Merry Christmas'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '1994-10-28'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 10

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/61ulfFSmmxMhc2wCdmdMkN'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks= row['track']['album']['total_tracks']
    album_urls = row['track']['album']['external_urls']['spotify']
    print(album_name)
    album_element = {'album_id':album_id,
                     'name':album_name, 
                     'release_date':album_release_date, 
                     'total_tracks':album_total_tracks,
                     'urls':album_urls
                    }
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '61ulfFSmmxMhc2wCdmdMkN',
#   'name': 'Merry Christmas',
#   'release_date': '1994-10-28',
#   'total_tracks': 10,
#   'urls': 'https://open.spotify.com/album/61ulfFSmmxMhc2wCdmdMkN'},
#  {'album_id': '2wyHNTisH8PtZG8OG58xr6',
#   'name': 'The Singles: Echoes from the Edge of Heaven',
#   'release_date': '2023-07-07',
#   'total_tracks': 16,
#   'urls': 'https://open.spotify.com/album/2wyHNTisH8PtZG8OG58xr6'},
#  {'album_id': '34wa3zf2prXFMk47t9zHFG',
#   'name': 'Merry Christmas From Brenda Lee',
#   'release_date': '1964-10-19',
#   'total_tracks': 12,
#   'urls': 'https://open.spotify.com/album/34wa3zf2prXFMk47t9zHFG'},
#  {'album_id': '3wivyOdotHWZ9dcuXMjPKT',
#   'name': 'Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)',
#   'release_date': '1957-12-02',
#   'total_tracks': 2,
#   'urls': 'https://open.spotify.com/album/3wivyOdotHWZ9dcuXMjPKT'},
#  {'album_id': '27MNgBEnLCKoafz1g2Zu97',
#   'name': 'Santa Tell Me',
# ...

# %%
data['items'][0] #['track']['artists'][0]['id']
# Out:
# {'added_at': '2023-12-21T09:51:14Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iHNK0tOyZPYnBU7nGAgpQ'},
#      'href': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ',
#      'id': '4iHNK0tOyZPYnBU7nGAgpQ',
#      'name': 'Mariah Carey',
#      'type': 'artist',
#      'uri': 'spotify:artist:4iHNK0tOyZPYnBU7nGAgpQ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
# ...

# %%
artist_list=[]
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
              artist_dict = {'artist_id':artist['id'],
                 'artist_name':artist['name'],
                 'external_url':artist['href']}
    artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '4iHNK0tOyZPYnBU7nGAgpQ',
#   'artist_name': 'Mariah Carey',
#   'external_url': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ'},
#  {'artist_id': '5lpH0xAS4fVfLkACg9DAuM',
#   'artist_name': 'Wham!',
#   'external_url': 'https://api.spotify.com/v1/artists/5lpH0xAS4fVfLkACg9DAuM'},
#  {'artist_id': '4cPHsZM98sKzmV26wlwD2W',
#   'artist_name': 'Brenda Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/4cPHsZM98sKzmV26wlwD2W'},
#  {'artist_id': '38EmEgXkgK51MT2tPY0EoC',
#   'artist_name': 'Bobby Helms',
#   'external_url': 'https://api.spotify.com/v1/artists/38EmEgXkgK51MT2tPY0EoC'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '1GxkXlMwML1oSg5eLPiAz3',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track' ]['name']
    song_duration = row['track' ]['duration_ms']
    song_url=row['track' ]['external_urls']['spotify']
    song_popularity =row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element ={'song_id':song_id,
                'song_name':song_name,
                'duration_ms': song_duration, 
                'url': song_url,
                'popularity':song_popularity,
                'song_added':song_added, 
                'album id':album_id,
                'artist_id':artist_id
               }
song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  61ulfFSmmxMhc2wCdmdMkN                                    Merry Christmas
# 1  2wyHNTisH8PtZG8OG58xr6        The Singles: Echoes from the Edge of Heaven
# 2  34wa3zf2prXFMk47t9zHFG                    Merry Christmas From Brenda Lee
# 3  3wivyOdotHWZ9dcuXMjPKT  Jingle Bell Rock/Captain Santa Claus (And His ...
# 4  27MNgBEnLCKoafz1g2Zu97                                      Santa Tell Me
#
#   release_date  total_tracks  \
# 0   1994-10-28            10
# 1   2023-07-07            16
# 2   1964-10-19            12
# 3   1957-12-02             2
# 4   2014-11-24             1
#
#                                                 urls
# 0  https://open.spotify.com/album/61ulfFSmmxMhc2w...
# 1  https://open.spotify.com/album/2wyHNTisH8PtZG8...
# 2  https://open.spotify.com/album/34wa3zf2prXFMk4...
# 3  https://open.spotify.com/album/3wivyOdotHWZ9dc...
# 4  https://open.spotify.com/album/27MNgBEnLCKoafz...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   urls          50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#song_df
song_df = pd.DataFrame.from_dict(song_list)album

# %%
song_df
# Out:
#                   song_id song_name  duration_ms  \
# 0  4MjDJD8cW7iVeWInc2Bdyj    MONACO       267194
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/4MjDJD8cW7iVeWI...          95
#
#              song_added                album id               artist_id
# 0  2023-12-21T09:51:14Z  4FftCsAcXXD1nFO9RFUNFO  4q3ewBCX7sLwd24euuV69X

# %%
song_df.head
# Out:
# <bound method NDFrame.head of                   song_id song_name  duration_ms  \
# 0  4MjDJD8cW7iVeWInc2Bdyj    MONACO       267194
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/4MjDJD8cW7iVeWI...          95
#
#              song_added                album id               artist_id
# 0  2023-12-21T09:51:14Z  4FftCsAcXXD1nFO9RFUNFO  4q3ewBCX7sLwd24euuV69X  >

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  61ulfFSmmxMhc2wCdmdMkN                                    Merry Christmas
# 1  2wyHNTisH8PtZG8OG58xr6        The Singles: Echoes from the Edge of Heaven
# 2  34wa3zf2prXFMk47t9zHFG                    Merry Christmas From Brenda Lee
# 3  3wivyOdotHWZ9dcuXMjPKT  Jingle Bell Rock/Captain Santa Claus (And His ...
# 4  27MNgBEnLCKoafz1g2Zu97                                      Santa Tell Me
#
#   release_date  total_tracks  \
# 0   1994-10-28            10
# 1   2023-07-07            16
# 2   1964-10-19            12
# 3   1957-12-02             2
# 4   2014-11-24             1
#
#                                                 urls
# 0  https://open.spotify.com/album/61ulfFSmmxMhc2w...
# 1  https://open.spotify.com/album/2wyHNTisH8PtZG8...
# 2  https://open.spotify.com/album/34wa3zf2prXFMk4...
# 3  https://open.spotify.com/album/3wivyOdotHWZ9dc...
# 4  https://open.spotify.com/album/27MNgBEnLCKoafz...

# %%
song_df
# Out:
#                   song_id song_name  duration_ms  \
# 0  4MjDJD8cW7iVeWInc2Bdyj    MONACO       267194
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/4MjDJD8cW7iVeWI...          95
#
#              song_added                album id               artist_id
# 0  2023-12-21T09:51:14Z  4FftCsAcXXD1nFO9RFUNFO  4q3ewBCX7sLwd24euuV69X

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      1 non-null      object
#  1   song_name    1 non-null      object
#  2   duration_ms  1 non-null      int64
#  3   url          1 non-null      object
#  4   popularity   1 non-null      int64
#  5   song_added   1 non-null      datetime64[ns, UTC]
#  6   album id     1 non-null      object
#  7   artist_id    1 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 196.0+ bytes
